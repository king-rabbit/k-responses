# %%
import lxml
import requests
import time
import sys
import pandas as pd
from datetime import date, timedelta
from tqdm.notebook import tqdm
import json
import os
import googleapiclient.discovery
# Out:
# C:\Users\user\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\user\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
#DEVELOPER_KEY = "AIzaSyAwpKUgDT7W_nEhR8UXJFvgibUXWQhPBeo"
DEVELOPER_KEY = "AIzaSyC_wM6f-Cbi043Hyw-PtGJ69KDzfrgnBdA"

# %%
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
sd = date(2020, 7, 1)
week = timedelta(weeks=1)
day = timedelta(days=1)
ed = sd + week -day

# %%
video_title = []
video_id = []
channel_title = []
channel_id = []
description = []
pub_date = []


for i in range(52):
    pa_date = sd.strftime('%Y-%m-%d') + 'T00:00:00Z'
    pb_date = ed.strftime('%Y-%m-%d') + 'T23:59:59Z'
    
    search_response = youtube.search().list(
        q='한국 반응',
        part="id, snippet",
        maxResults=50, #최대값
        publishedAfter = pa_date,
        publishedBefore = pb_date,
        #videoCategoryId=10,   # music:10,  videoblogging:21, People & Blogs:22, Entertainment:24
        type = 'video',
        order = 'relevance'
    ).execute()


    for search_result in search_response.get("items", []):
        video_title.append(search_result["snippet"]["title"])
        video_id.append(search_result["id"]["videoId"])
        channel_title.append(search_result["snippet"]["channelTitle"])
        channel_id.append(search_result["snippet"]["channelId"])
        description.append(search_result["snippet"]["description"])
        pub_date.append(search_result["snippet"]["publishTime"])
        
    sd += week
    ed = sd + week - day

# %%
video_df = pd.DataFrame({'title':video_title, 'video_id':video_id, 'channel_title':channel_title, 'channel_id':channel_id, 'description':description, 'date':pub_date})

# %%
video_df.to_csv('youtube_video_list.csv', encoding='utf-8-sig')

# %%
video_df
# Out:
#                                                   title     video_id  \
# 0                          한국 예능 야구 레전드를 보고 현웃터진 미국인 반응  AEl5RAzF0lQ
# 1                                 해외에서 반응 난리 났다는 한국 디저트  wYp0kz2kgKE
# 2     &quot;한국 스타일 무섭네!&quot; 한국의 건물사진에 깜짝놀란 스페인 반응과...  It69uJHJIuA
# 3     한국 LG OLED TV의인기비결은???해외반응 – 일본이것이 한국의 기술이다!!일...  1SIA3ukXyhc
# 4           한국 마스크를 처음 써보고 놀라운 반응을 보여주는 이탈리아 남자! 그 이유는?  3LwSAs3eeQA
# ...                                                 ...          ...
# 2536  중국반응│역사를 잊고 있는 중국의 젊은이들에게 날리는 일침│일본에 대한 한국과 중국...  1WNLKDTLIfo
# 2537  [단독외국인반응] &quot;90%가 이걸 진짜 가지고 다녀???&quot; 한국 ...  O6OP1Nb0Zlw
# 2538  【일본반응】 일본에서는 당연하다고 생각하지만 한국과는 다른 모습에 충격받은 일본 &...  aDF9TPVn-vE
# 2539  해외반응 | &quot;한국만은 빼앗길 수 없어!&quot; 한국이 초청되자 초조함...  fnYdfanH1ag
# 2540  일본반응 l 수습불가 돌출행동에 기겁하는 일본, 한국에서 쉽고 가능했던 일이 일본에...  a4xGwAt2QjE
#
#              channel_title                channel_id  \
# 0                  BODA 보다  UCoCvTlU0KpNYwnMIgs7MPrA
# 1                      뉴스킹  UClOg34aPlf3GWZZ6ojt0WYQ
# 2                     구네스북  UClHJcrFMOxCEPjjg6WlTmPw
# 3                      데보이  UC9Uf0ZCFKKy65uCOf6oCrOQ
# 4     레만 Reman [로마사는 한국남자]  UC0MhsY1Nc467re-66o6xwRg
# ...                    ...                       ...
# 2536              중국어로 [路]  UCxV6HwAqpzkAN1J2s9LolgQ
# 2537                  존크TV  UCitaXlLp5Oy0aKmH2_y0xFw
# 2538                  잇슈TV  UCRwAxNNK8_fg9ylPyjqSAfA
# 2539                해외리얼반응  UCPwsW_PosWeZHa1bMqKibcw
# 2540  넘버원 해외반응 • 조회수 183만회  UClu2TJC8VLYbczRCiyDVX6w
#
#                                             description                  date
# 0     KBO #한국야구 #예능짤 #MLB 오늘은 미국에서 온 김태균씨와 한국에 레전드 야...  2020-07-02T10:29:13Z
# 1     한국 #근황 #해외반응 해외에서 난리라는 한국 디저트 근황 "돈 걱정 없이 전부 다...  2020-07-03T03:25:31Z
# 2     한국의 건물사진에 깜짝놀란 스페인 반응과 네티즌 반응을 다뤘습니다. * 구네스북 그...  2020-07-06T03:00:04Z
# 3     해외반응#한국해외반응#일본 한국 LG OLED TV의 인기비결은??? 해외반응 – ...  2020-07-04T14:14:30Z
# 4     이탈리아 남자 알레한테 한국 마스크를 선물해주었습니다. 알레 반응이 정말 대박이네요...  2020-07-01T12:27:20Z
# ...                                                 ...                   ...
# 2536  지금도 많은 중국인들이 일본과 관련하여 역사를 잊지 않고 있습니다​ 아니, 그런줄 ...  2021-06-23T10:00:01Z
# 2537  구독하기 : https://bit.ly/39beO6A 영상을 시청해주셔서 감사합니다...  2021-06-27T09:13:05Z
# 2538  일본반응 일본에서는 당연하다고 생각하지만 한국과는 다른 모습에 충격받은 일본 "한국...  2021-06-29T14:59:01Z
# 2539  중국 #중국미국 #신냉전 얼마 전 열린 G7 정상회의를 한 문장으로 정리한다면 '중...  2021-06-26T23:09:21Z
# 2540  세계속에서 한국의 영향력을 알아보는 넘버원 해외반응 입니다. 영상을 재미있게 보셨다...  2021-06-24T14:31:04Z
#
# [2541 rows x 6 columns]

# %%
video_id = list(df['video_id'])

# %%
comment_json = []
for vidx in tqdm(video_id):
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=vidx
    )
    try:
        response = request.execute()
        comment_list = response['items']
        for i in range(len(comment_list)):
            comment_json.append(comment_list[i]['snippet']['topLevelComment']['snippet'])
    except:
        pass

comment_df = pd.DataFrame(comment_json)
