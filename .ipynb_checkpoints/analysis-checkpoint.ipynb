# %%
import pandas as pd
import numpy as np
import operator
import datetime
import pyecharts
from eunjeon import Mecab 
from collections import Counter
from collections import defaultdict

# %%
videos = pd.read_csv('data/youtube_video_list.csv')
videos2 = pd.read_csv('data/youtube_video_list_2.csv')
df = pd.concat([videos, videos2])

# %%
del df['Unnamed: 0']
df = df.drop_duplicates()

# %%
df = df.reset_index()

# %%
df['channel_title'].value_counts()[:50]
# Out:
# 존크TV                        154
# 대고구려제국                      139
# 소녀통신 • 조회수239만회              80
# Kraze Reaction               79
# 중국어로 [路]                     77
# 세상을말하다                       75
# QUEEN SOHYANG                74
# 코리안브로스                       69
# 비더탑                          65
# 고춧가루TV                       63
# ALL THE K-JAM 올더케이잼          61
# 국뽕                           54
# 에이 스토리 A STORY               49
# 구네스북                         49
# 뉴스킹                          47
# 해외리얼반응                       47
# 사이다 일본반응 • 조회수 73만회          44
# 레만 Reman [로마사는 한국남자]         43
# BODA 보다                      42
# 사건왕-[해외반응, 외신뉴스]             41
# tvN D ENT                    41
# 다른생각TV                       38
# 베이비버그 BabyBug                38
# 해외반응 탐사대                     37
# 올타구 · 시사 이슈 문화               36
# 월드 댓글TV                      36
# 이슈특급                         36
# 잇슈TV                         30
# 션데일리 리서치                     29
# 팩튜브                          27
# 해외네티즌반응                      27
# 꾼맨 KKUNMAN                   27
# 케파튜브· 조회수 1384만회             26
# Eating what is Given 오스틴     25
# 한눈에 세계를                      25
# CLAB                         23
# JTBC Voyage                  22
# Korean Jaeho                 22
# 유럽 속 한국KOREA IN EUROPE       21
# 오버씨 overseas                 21
# 영알남YAN                       21
# 뉴스탓                          20
# 와트맨                          20
# 어썸 코리아 Awesome KOREA         20
# 해외반응                         20
# 이슈특파원                        20
# JAY G_제이 G                   19
# 소문의 중심                       19
# 이시각 해외반응                     18
# 지니튜브_이슈채널                    18
# Name: channel_title, dtype: int64

# %%
tagger = Mecab() 
vocabs = []
for title in df['title']:
    nouns = tagger.nouns(title)
    for noun in nouns:
        vocabs.append(noun)

# %%
result = Counter(vocabs)

# %%
Counter(vocabs).most_common()
# Out:
# [('반응', 4261),
#  ('한국', 3740),
#  ('일본', 2176),
#  ('해외', 1784),
#  ('외국인', 979),
#  ('리액션', 763),
#  ('이유', 619),
#  ('중국', 566),
#  ('미국', 448),
#  ('세계', 411),
#  ('자막', 349),
#  ('한글', 343),
#  ('한국인', 323),
#  ('일본인', 291),
#  ('충격', 274),
#  ('네티즌', 241),
#  ('상황', 239),
#  ('방탄소년단', 236),
#  ('사람', 200),
#  ('수', 169),
#  ('방송', 158),
#  ('영상', 155),
#  ('모음', 151),
#  ('처음', 149),
#  ('거', 147),
#  ('일', 135),
#  ('외국', 133),
#  ('말', 132),
#  ('위', 131),
#  ('영화', 127),
#  ('드라마', 122),
#  ('ㅣ', 122),
#  ('커플', 115),
#  ('소향', 114),
#  ('대만', 110),
#  ('나라', 107),
#  ('것', 107),
#  ('이것', 106),
#  ('여자', 105),
#  ('미국인', 104),
#  ('년', 104),
#  ('경악', 103),
#  ('국제', 99),
#  ('댓글', 99),
#  ('친구', 98),
#  ('영국', 97),
#  ('최고', 94),
#  ('미사일', 92),
#  ('중', 89),
#  ('남자', 88),
#  ('비교', 87),
#  ('먹방', 87),
#  ('때', 86),
#  ('현지', 84),
#  ('우리', 84),
#  ('탄', 83),
#  ('ㄷ', 82),
#  ('음식', 82),
#  ('베트남', 82),
#  ('만', 80),
#  ('편', 80),
#  ('사진', 79),
#  ('문화', 79),
#  ('대한민국', 79),
#  ('폭발', 79),
#  ('선진국', 79),
#  ('뮤', 79),
#  ('급', 78),
#  ('무대', 78),
#  ('레전드', 77),
#  ('어로', 77),
#  ('전', 76),
#  ('군사력', 75),
#  ('블랙', 71),
#  ('노래', 71),
#  ('국', 71),
#  ('역대', 70),
#  ('개발', 67),
#  ('감동', 67),
#  ('공개', 66),
#  ('기술', 63),
#  ('소식', 63),
#  ('분노', 63),
#  ('중국인', 63),
#  ('가수', 63),
#  ('핑크', 62),
#  ('영어', 62),
#  ('내', 62),
#  ('손흥민', 61),
#  ('나', 60),
#  ('댄스', 60),
#  ('방탄', 60),
#  ('러시아', 59),
#  ('백신', 59),
#  ('전투기', 58),
#  ('무기', 57),
#  ('경제', 57),
#  ('팬', 57),
#  ('사랑', 56),
#  ('한류', 56),
#  ('난리', 54),
#  ('이탈리아', 54),
#  ('글', 54),
#  ('이게', 54),
#  ('때문', 53),
#  ('현무', 52),
#  ('차', 52),
#  ('미', 52),
#  ('가족', 51),
#  ('등', 51),
#  ('현실', 51),
#  ('라이브', 51),
#  ('모습', 51),
#  ('극찬', 50),
#  ('가능', 49),
#  ('집', 49),
#  ('게', 49),
#  ('언론', 48),
#  ('순위', 48),
#  ('독일', 48),
#  ('유', 47),
#  ('차이', 47),
#  ('어서', 47),
#  ('대', 46),
#  ('눈물', 45),
#  ('원', 45),
#  ('수출', 45),
#  ('줄', 45),
#  ('분석', 44),
#  ('국가', 44),
#  ('주의', 44),
#  ('인기', 43),
#  ('단독', 43),
#  ('뽕', 43),
#  ('걸', 43),
#  ('후', 43),
#  ('분', 43),
#  ('비', 43),
#  ('트', 42),
#  ('여행', 42),
#  ('아이', 42),
#  ('번', 42),
#  ('기업', 41),
#  ('뉴스', 41),
#  ('강대국', 40),
#  ('감탄', 40),
#  ('이걸', 40),
#  ('팝', 39),
#  ('맛', 39),
#  ('인정', 39),
#  ('지하철', 39),
#  ('하나', 39),
#  ('버터', 39),
#  ('조', 38),
#  ('엄마', 38),
#  ('생각', 38),
#  ('대박', 38),
#  ('비디오', 38),
#  ('아미', 38),
#  ('보컬', 38),
#  ('무시', 37),
#  ('선물', 37),
#  ('스타', 37),
#  ('축구', 37),
#  ('김치', 37),
#  ('개', 36),
#  ('국민', 36),
#  ('학생', 36),
#  ('역사', 36),
#  ('다이너마이트', 36),
#  ('스테이', 36),
#  ('행동', 35),
#  ('국군', 35),
#  ('최초', 35),
#  ('서울', 35),
#  ('장', 35),
#  ('브레이브걸스', 35),
#  ('최근', 34),
#  ('수준', 34),
#  ('화', 34),
#  ('시', 33),
#  ('이상', 33),
#  ('한국어', 33),
#  ('아기', 33),
#  ('아이돌', 33),
#  ('정부', 33),
#  ('코로나', 33),
#  ('속', 33),
#  ('몰카', 33),
#  ('윤', 33),
#  ('경험', 32),
#  ('제품', 32),
#  ('브이', 32),
#  ('유럽', 32),
#  ('유명', 32),
#  ('실제', 32),
#  ('회', 32),
#  ('미녀', 32),
#  ('정도', 32),
#  ('시간', 32),
#  ('이야기', 32),
#  ('골', 32),
#  ('체코', 32),
#  ('전쟁', 31),
#  ('성공', 31),
#  ('리뷰', 31),
#  ('생활', 31),
#  ('이', 31),
#  ('가지', 31),
#  ('발표', 31),
#  ('입', 31),
#  ('치킨', 31),
#  ('코치', 31),
#  ('길거리', 30),
#  ('프랑스', 30),
#  ('코리아', 30),
#  ('부모', 30),
#  ('우익', 30),
#  ('미얀마', 30),
#  ('배', 30),
#  ('채팅', 30),
#  ('랜덤', 30),
#  ('당황', 29),
#  ('전문가', 29),
#  ('방문', 29),
#  ('외신', 28),
#  ('튜버', 28),
#  ('군', 28),
#  ('뮤직', 28),
#  ('공연', 28),
#  ('알렝', 28),
#  ('롤린', 28),
#  ('삼성', 27),
#  ('보도', 27),
#  ('올림픽', 27),
#  ('케이', 27),
#  ('명', 27),
#  ('북한', 27),
#  ('리얼', 27),
#  ('곡', 27),
#  ('필리핀', 26),
#  ('시작', 26),
#  ('아시아', 26),
#  ('교육', 26),
#  ('눈', 26),
#  ('커버', 26),
#  ('고딩', 26),
#  ('아이유', 26),
#  ('그', 25),
#  ('일상', 25),
#  ('인생', 25),
#  ('잠수함', 24),
#  ('미래', 24),
#  ('연예인', 24),
#  ('기술력', 24),
#  ('현재', 24),
#  ('소름', 24),
#  ('부부', 24),
#  ('버전', 24),
#  ('전차', 24),
#  ('부대', 24),
#  ('빌보드', 24),
#  ('아내', 24),
#  ('남녀', 24),
#  ('기적', 23),
#  ('인터뷰', 23),
#  ('핵', 23),
#  ('최강', 23),
#  ('뭐', 23),
#  ('남편', 23),
#  ('음악', 22),
#  ('선수', 22),
#  ('억', 22),
#  ('군대', 22),
#  ('필요', 22),
#  ('해병대', 22),
#  ('건', 22),
#  ('등장', 22),
#  ('홍보', 22),
#  ('반전', 22),
#  ('돈', 22),
#  ('댄서', 22),
#  ('넷플릭스', 21),
#  ('아베', 21),
#  ('실화', 21),
#  ('과자', 21),
#  ('손', 21),
#  ('경기', 21),
#  ('난', 21),
#  ('덕', 21),
#  ('스텔스', 21),
#  ('창', 21),
#  ('독도', 21),
#  ('한식', 21),
#  ('춤', 21),
#  ('브레이크', 21),
#  ('회수', 20),
#  ('최신', 20),
#  ('군사', 20),
#  ('아빠', 20),
#  ('어게인', 20),
#  ('여성', 20),
#  ('디', 20),
#  ('운동', 20),
#  ('결국', 20),
#  ('앞', 20),
#  ('발언', 20),
#  ('삼겹살', 20),
#  ('소녀', 20),
#  ('자동차', 20),
#  ('급식', 20),
#  ('딸', 20),
#  ('마스크', 19),
#  ('기록', 19),
#  ('의식', 19),
#  ('최악', 19),
#  ('첨단', 19),
#  ('라면', 19),
#  ('도쿄', 19),
#  ('시장', 19),
#  ('쇼', 19),
#  ('한복', 19),
#  ('너', 19),
#  ('日', 19),
#  ('밤', 19),
#  ('맛집', 19),
#  ('도전', 19),
#  ('정신', 19),
#  ('콘서트', 19),
#  ('광고', 19),
#  ('아저씨', 19),
#  ('밥', 19),
#  ('지민', 19),
#  ('홈', 19),
#  ('정국', 19),
#  ('이해', 18),
#  ('시민', 18),
#  ('소개', 18),
#  ('인도', 18),
#  ('선택', 18),
#  ('호주', 18),
#  ('상상', 18),
#  ('마트', 18),
#  ('술', 18),
#  ('속보', 18),
#  ('어디', 18),
#  ('식당', 18),
#  ('장면', 18),
#  ('천', 18),
#  ('하이라이트', 18),
#  ('후기', 18),
#  ('열광', 17),
#  ('기사', 17),
#  ('인도네시아', 17),
#  ('다리', 17),
#  ('외', 17),
#  ('사친', 17),
#  ('유일', 17),
#  ('열풍', 17),
#  ('배우', 17),
#  ('추월', 17),
#  ('방법', 17),
#  ('소리', 17),
#  ('게임', 17),
#  ('한우', 17),
#  ('끝', 17),
#  ('특수', 17),
#  ('그룹', 17),
#  ('실력', 17),
#  ('한국군', 17),
#  ('오', 17),
#  ('유튜브', 17),
#  ('가난', 17),
#  ('존재', 17),
#  ('핫클립', 17),
#  ('드', 17),
#  ('시골', 17),
#  ('공포', 17),
#  ('커뮤니티', 16),
#  ('특징', 16),
#  ('병원', 16),
#  ('사실', 16),
#  ('대응', 16),
#  ('대표', 16),
#  ('감사', 16),
#  ('압도', 16),
#  ('미군', 16),
#  ('욕', 16),
#  ('남', 16),
#  ('완전', 16),
#  ('초', 16),
#  ('도움', 16),
#  ('버스', 16),
#  ('자존심', 16),
#  ('날', 16),
#  ('출연', 16),
#  ('스위트', 16),
#  ('캠', 16),
#  ('마술', 16),
#  ('방역', 15),
#  ('반도체', 15),
#  ('할머니', 15),
#  ('영국인', 15),
#  ('대학생', 15),
#  ('자주포', 15),
#  ('전체', 15),
#  ('진출', 15),
#  ('타임즈', 15),
#  ('웃음', 15),
#  ('요청', 15),
#  ('물건', 15),
#  ('채널', 15),
#  ('풀', 15),
#  ('흑표', 15),
#  ('안전', 15),
#  ('액션', 15),
#  ('땅', 15),
#  ('싱어', 15),
#  ('하루', 15),
#  ('편의점', 15),
#  ('살', 15),
#  ('월', 15),
#  ('태권', 15),
#  ('신곡', 15),
#  ('스페인', 14),
#  ('방', 14),
#  ('모두', 14),
#  ('침몰', 14),
#  ('무릎', 14),
#  ('발전', 14),
#  ('질투', 14),
#  ('간', 14),
#  ('월드컵', 14),
#  ('호', 14),
#  ('中', 14),
#  ('직원', 14),
#  ('글로벌', 14),
#  ('팀', 14),
#  ('자랑', 14),
#  ('주목', 14),
#  ('척', 14),
#  ('시스템', 14),
#  ('순간', 14),
#  ('구독자', 14),
#  ('아이스크림', 14),
#  ('연습', 14),
#  ('형', 14),
#  ('자신', 14),
#  ('구이', 14),
#  ('기자', 14),
#  ('거리', 14),
#  ('마마', 14),
#  ('예능', 13),
#  ('포기', 13),
#  ('화제', 13),
#  ('체험', 13),
#  ('누구', 13),
#  ('양심', 13),
#  ('성장', 13),
#  ('무엇', 13),
#  ('캐나다', 13),
#  ('평가', 13),
#  ('유학', 13),
#  ('세대', 13),
#  ('불매', 13),
#  ('태국', 13),
#  ('이건', 13),
#  ('치안', 13),
#  ('키', 13),
#  ('승', 13),
#  ('고등', 13),
#  ('해', 13),
#  ('프랑스인', 13),
#  ('총리', 13),
#  ('관광', 13),
#  ('폭풍', 13),
#  ('초토', 13),
#  ('정체', 13),
#  ('학교', 13),
#  ('태극기', 13),
#  ('노', 13),
#  ('안무', 13),
#  ('왕', 13),
#  ('동안', 13),
#  ('세상', 13),
#  ('대취타', 13),
#  ('초대', 13),
#  ('그래미', 13),
#  ('기생충', 13),
#  ('제시', 13),
#  ('손님', 13),
#  ('리', 13),
#  ('클립', 13),
#  ('의외', 12),
#  ('주', 12),
#  ('항공모함', 12),
#  ('의사', 12),
#  ('이제', 12),
#  ('목소리', 12),
#  ('레이더', 12),
#  ('나훈아', 12),
#  ('위기', 12),
#  ('희망', 12),
#  ('트럼프', 12),
#  ('특별', 12),
#  ('카페', 12),
#  ('국내', 12),
#  ('임신', 12),
#  ('뒤', 12),
#  ('공감', 12),
#  ('탑재', 12),
#  ('특집', 12),
#  ('전통', 12),
#  ('토트넘', 12),
#  ('화장실', 12),
#  ('동맹', 12),
#  ('직업', 12),
#  ('열', 12),
#  ('시절', 12),
#  ('승리', 12),
#  ('등극', 12),
#  ('프로', 12),
#  ('도시', 12),
#  ('콜', 12),
#  ('진심', 12),
#  ('듯', 12),
#  ('업', 12),
#  ('트롯', 12),
#  ('달', 12),
#  ('마리아', 12),
#  ('전설', 12),
#  ('박효신', 12),
#  ('최준', 12),
#  ('긴장', 11),
#  ('국산', 11),
#  ('클라', 11),
#  ('점', 11),
#  ('요리', 11),
#  ('비판', 11),
#  ('가슴', 11),
#  ('韓', 11),
#  ('결과', 11),
#  ('핫', 11),
#  ('위상', 11),
#  ('최대', 11),
#  ('백', 11),
#  ('짜장면', 11),
#  ('논란', 11),
#  ('뜻밖', 11),
#  ('생산', 11),
#  ('지금', 11),
#  ('이거', 11),
#  ('통쾌', 11),
#  ('마지막', 11),
#  ('시리즈', 11),
#  ('박싱', 11),
#  ('기억', 11),
#  ('진돗개', 11),
#  ('중국어', 11),
#  ('쓰레기', 11),
#  ('행복', 11),
#  ('관심', 11),
#  ('멤버', 11),
#  ('포함', 11),
#  ('후회', 11),
#  ('문제', 11),
#  ('갈비', 11),
#  ('유행', 11),
#  ('표현', 11),
#  ('헬', 11),
#  ('여기', 11),
#  ('가사', 11),
#  ('법', 11),
#  ('마이크', 11),
#  ('질문', 11),
#  ('러브', 11),
#  ('대회', 11),
#  ('카타르', 11),
#  ('떼', 11),
#  ('시즌', 11),
#  ('직', 11),
#  ('적', 11),
#  ('카디', 11),
#  ('부자', 11),
#  ('번역', 11),
#  ('접종', 11),
#  ('귀', 11),
#  ('크리스천', 11),
#  ('사이트', 10),
#  ('작전', 10),
#  ('걱정', 10),
#  ('자국', 10),
#  ('관계', 10),
#  ('한숨', 10),
#  ('교수', 10),
#  ('칼럼', 10),
#  ('역전', 10),
#  ('엠', 10),
#  ('훈련', 10),
#  ('사업', 10),
#  ('당장', 10),
#  ('예상', 10),
#  ('매력', 10),
#  ('사이', 10),
#  ('이스', 10),
#  ('혁신', 10),
#  ('퀴즈', 10),
#  ('혐한', 10),
#  ('터키', 10),
#  ('한필', 10),
#  ('사거리', 10),
#  ('천재', 10),
#  ('브라질', 10),
#  ('리호', 10),
#  ('소주', 10),
#  ('시대', 10),
#  ('핵보유국', 10),
#  ('칭찬', 10),
#  ('엔터', 10),
#  ('인', 10),
#  ('퍼포먼스', 10),
#  ('영토', 10),
#  ('결혼', 10),
#  ('볶음', 10),
#  ('키스', 10),
#  ('모델', 10),
#  ('명곡', 10),
#  ('민족', 10),
#  ('패배', 10),
#  ('군인', 10),
#  ('뻔', 10),
#  ('수주', 10),
#  ('천만', 10),
#  ('나이', 10),
#  ('오열', 10),
#  ('수상', 10),
#  ('기', 10),
#  ('씨', 10),
#  ('비리', 10),
#  ('시티', 10),
#  ('슈가', 10),
#  ('클럽', 10),
#  ('선', 10),
#  ('멕시코', 10),
#  ('잼', 10),
#  ('예선', 10),
#  ('펜', 10),
#  ('롯', 10),
#  ('장모님', 10),
#  ('김', 10),
#  ('아들', 10),
#  ('가정집', 10),
#  ('청하', 10),
#  ('소개팅', 10),
#  ('지미', 10),
#  ('팰런', 10),
#  ('빈센조', 10),
#  ('정복', 9),
#  ('고민', 9),
#  ('진실', 9),
#  ('무장', 9),
#  ('선정', 9),
#  ('열등감', 9),
#  ('빵', 9),
#  ('위엄', 9),
#  ('고급', 9),
#  ('국행', 9),
#  ('증거', 9),
#  ('맥주', 9),
#  ('개월', 9),
#  ('여배우', 9),
#  ('회사', 9),
#  ('레벨', 9),
#  ('폭', 9),
#  ('비긴', 9),
#  ('슈퍼', 9),
#  ('능력', 9),
#  ('산업', 9),
#  ('후진국', 9),
#  ('해결', 9),
#  ('사용', 9),
#  ('패션', 9),
#  ('생일', 9),
#  ('규제', 9),
#  ('내용', 9),
#  ('사연', 9),
#  ('이미지', 9),
#  ('반', 9),
#  ('전문', 9),
#  ('복면', 9),
#  ('가왕', 9),
#  ('얼굴', 9),
#  ('전환', 9),
#  ('웹툰', 9),
#  ('식', 9),
#  ('물', 9),
#  ('불고기', 9),
#  ('초월', 9),
#  ('실시간', 9),
#  ('곳', 9),
#  ('포레', 9),
#  ('스텔라', 9),
#  ('여친', 9),
#  ('불닭', 9),
#  ('현대', 9),
#  ('영웅', 9),
#  ('롤', 9),
#  ('국산화', 9),
#  ('수입', 9),
#  ('덕분', 9),
#  ('결정', 9),
#  ('비빔밥', 9),
#  ('가짜', 9),
#  ('발', 9),
#  ('근황', 9),
#  ('여러분', 9),
#  ('티비', 9),
#  ('떡볶이', 9),
#  ('꿈', 9),
#  ('요즘', 9),
#  ('북', 9),
#  ('산', 9),
#  ('데', 9),
#  ('사건', 9),
#  ('뷰', 9),
#  ('출신', 9),
#  ('전역', 9),
#  ('메뉴', 9),
#  ('스가', 9),
#  ('데뷔', 9),
#  ('좌절', 9),
#  ('안', 9),
#  ('임영웅', 9),
#  ('장인', 9),
#  ('윤여정', 9),
#  ('놈', 9),
#  ('기겁', 9),
#  ('싹', 9),
#  ('일반인', 9),
#  ('존', 9),
#  ('언니', 9),
#  ('에일리', 9),
#  ('무', 9),
#  ('뚜', 9),
#  ('샤이니', 9),
#  ('온도', 9),
#  ('디스', 9),
#  ('마이클잭슨', 9),
#  ('강아지', 8),
#  ('한마디', 8),
#  ('문', 8),
#  ('의료', 8),
#  ('아이즈', 8),
#  ('리그', 8),
#  ('비난', 8),
#  ('사회', 8),
#  ('대통령', 8),
#  ('와이프', 8),
#  ('대마도', 8),
#  ('사무총장', 8),
#  ('점령', 8),
#  ('페루', 8),
#  ('뉴욕', 8),
#  ('경쟁력', 8),
#  ('투자', 8),
#  ('달성', 8),
#  ('급상승', 8),
#  ('점유', 8),
#  ('도입', 8),
#  ('김밥', 8),
#  ('레드', 8),
#  ('자체', 8),
#  ('그녀', 8),
#  ('더블', 8),
#  ('여론', 8),
#  ('강', 8),
#  ('건조', 8),
#  ('해제', 8),
#  ('시청', 8),
#  ('흥분', 8),
#  ('변화', 8),
#  ('이민', 8),
#  ('감', 8),
#  ('이란', 8),
#  ('공부', 8),
#  ('천국', 8),
#  ('계획', 8),
#  ('속도', 8),
#  ('협력', 8),
#  ('힙합', 8),
#  ('강제', 8),
#  ('신', 8),
#  ('필수', 8),
#  ('몽골', 8),
#  ('효과', 8),
#  ('무한', 8),
#  ('정리', 8),
#  ('비밀', 8),
#  ('원조', 8),
#  ('해석', 8),
#  ('자기', 8),
#  ('마음', 8),
#  ('티', 8),
#  ('지지', 8),
#  ('기본', 8),
#  ('오픈', 8),
#  ('할아버지', 8),
#  ('볶음밥', 8),
#  ('지도', 8),
#  ('축하', 8),
#  ('랩', 8),
#  ('상어', 8),
#  ('클라스', 8),
#  ('부산', 8),
#  ('오늘', 8),
#  ('원어민', 8),
#  ('여고생', 8),
#  ('조선', 8),
#  ('하우스', 8),
#  ('관', 8),
#  ('데이트', 8),
#  ('국밥', 8),
#  ('마법', 8),
#  ('탈출', 8),
#  ('범', 8),
#  ('꼬리', 8),
#  ('괴물', 8),
#  ('아리랑', 8),
#  ('정상', 8),
#  ('봄', 8),
#  ('숲', 8),
#  ('스토리', 8),
#  ('투', 8),
#  ('총사', 8),
#  ('남친', 8),
#  ('뷔', 8),
#  ('선미', 8),
#  ('훈', 8),
#  ('퀸', 8),
#  ('래퍼', 8),
#  ('몬스터', 8),
#  ('변국', 7),
#  ('국방', 7),
#  ('상대', 7),
#  ('성능', 7),
#  ('관련', 7),
#  ('전자', 7),
#  ('쓰', 7),
#  ('완료', 7),
#  ('수소', 7),
#  ('남성', 7),
#  ('사나이', 7),
#  ('구매', 7),
#  ('일제', 7),
#  ('보이스', 7),
#  ('길', 7),
#  ('격리', 7),
#  ('지구', 7),
#  ('사고', 7),
#  ('전투', 7),
#  ('무인', 7),
#  ('지원', 7),
#  ('마리', 7),
#  ('발사', 7),
#  ('판매', 7),
#  ('부동산', 7),
#  ('예측', 7),
#  ('파', 7),
#  ('통일', 7),
#  ('부정', 7),
#  ('장갑차', 7),
#  ('땐', 7),
#  ('럭', 7),
#  ('며느리', 7),
#  ('해군', 7),
#  ('택배', 7),
#  ('원전', 7),
#  ('격분', 7),
#  ('현장', 7),
#  ('태세', 7),
#  ('카드', 7),
#  ('식품', 7),
#  ('싱가포르', 7),
#  ('이슈', 7),
#  ('불시착', 7),
#  ('폭탄', 7),
#  ('인터넷', 7),
#  ('고백', 7),
#  ('준비', 7),
#  ('혼혈', 7),
#  ('거부', 7),
#  ('당신', 7),
#  ('기분', 7),
#  ('밍', 7),
#  ('존경', 7),
#  ('긴급', 7),
#  ('반성', 7),
#  ('사상', 7),
#  ('육회', 7),
#  ('가전제품', 7),
#  ('뿐', 7),
#  ('식사', 7),
#  ('후보', 7),
#  ('도로', 7),
#  ('파워', 7),
#  ('규모', 7),
#  ('삼성전자', 7),
#  ('연속', 7),
#  ('실패', 7),
#  ('차별', 7),
#  ('스케치북', 7),
#  ('유희열', 7),
#  ('호랑이', 7),
#  ('테스트', 7),
#  ('표절', 7),
#  ('미스터', 7),
#  ('역습', 7),
#  ('전략', 7),
#  ('세계인', 7),
#  ('완벽', 7),
#  ('그때', 7),
#  ('스완', 7),
#  ('소감', 7),
#  ('경고', 7),
#  ('비행기', 7),
#  ('어선', 7),
#  ('이탈리아인', 7),
#  ('틱톡', 7),
#  ('언급', 7),
#  ('이사', 7),
#  ('외교', 7),
#  ('아무', 7),
#  ('최후', 7),
#  ('위험', 7),
#  ('유저', 7),
#  ('마이클', 7),
#  ('박정현', 7),
#  ('삶', 7),
#  ('확보', 7),
#  ('분위기', 7),
#  ('걸까', 7),
#  ('탄식', 7),
#  ('머그', 7),
#  ('남미', 7),
#  ('고음', 7),
#  ('느낌', 7),
#  ('분야', 7),
#  ('이젠', 7),
#  ('새벽', 7),
#  ('미스트', 7),
#  ('프로듀서', 7),
#  ('조선업', 7),
#  ('혼자', 7),
#  ('선박', 7),
#  ('제작', 7),
#  ('시댁', 7),
#  ('사이다', 7),
#  ('여권', 7),
#  ('누가', 7),
#  ('고기', 7),
#  ('멸', 7),
#  ('칼날', 7),
#  ('단체', 7),
#  ('차단', 7),
#  ('시범', 7),
#  ('쓰리', 7),
#  ('기념', 7),
#  ('놀람', 7),
#  ('파티', 7),
#  ('안예은', 7),
#  ('시네마', 7),
#  ('명장면', 7),
#  ('로스트', 7),
#  ('아크', 7),
#  ('연애', 7),
#  ('박진영', 7),
#  ('미모', 7),
#  ('대결', 7),
#  ('유아', 7),
#  ('킬링', 7),
#  ('솥뚜껑', 7),
#  ('봄날', 7),
#  ('힙', 7),
#  ('녀', 7),
#  ('앤', 7),
#  ('에스파', 7),
#  ('국경', 7),
#  ('운전', 7),
#  ('매드', 7),
#  ('스타일', 6),
#  ('서비스', 6),
#  ('기대', 6),
#  ('美', 6),
#  ('브랜드', 6),
#  ('열도', 6),
#  ('대학', 6),
#  ('육군', 6),
#  ('고등학교', 6),
#  ('멸망', 6),
#  ('식량', 6),
#  ...]

# %%
countries = pd.read_excel('data/countries.xlsx')

# %%
countries_name = list(countries['국가'])

# %%
countries_people = [ country + '인' for country in countries_name ]

# %%
countries_np = defaultdict()
for country in countries_name:
    if country in result.keys():
        countries_np[country] = result[country]
    if country + '인' in result.keys():
        countries_np[country] += result[country]

# %%
countries_np= sorted(countries_np.items(), key=operator.itemgetter(1), reverse=True)

# %%
countries_np
# Out:
# [('일본', 4352),
#  ('중국', 1132),
#  ('미국', 896),
#  ('영국', 194),
#  ('베트남', 164),
#  ('러시아', 118),
#  ('대만', 110),
#  ('이탈리아', 108),
#  ('독일', 96),
#  ('프랑스', 60),
#  ('아시아', 52),
#  ('인도', 36),
#  ('체코', 32),
#  ('유럽', 32),
#  ('미얀마', 30),
#  ('북한', 27),
#  ('필리핀', 26),
#  ('캐나다', 26),
#  ('터키', 20),
#  ('인도네시아', 17),
#  ('스페인', 14),
#  ('태국', 13),
#  ('카타르', 11),
#  ('멕시코', 10),
#  ('브라질', 10),
#  ('몽골', 8),
#  ('이란', 8),
#  ('페루', 8),
#  ('싱가포르', 7),
#  ('이스라엘', 6),
#  ('콜롬비아', 6),
#  ('폴란드', 6),
#  ('홍콩', 5),
#  ('레바논', 5),
#  ('투르크메니스탄', 5),
#  ('스위스', 5),
#  ('아프리카', 5),
#  ('스리랑카', 4),
#  ('아르헨티나', 4),
#  ('파라과이', 4),
#  ('네덜란드', 4),
#  ('나이지리아', 4),
#  ('말레이시아', 3),
#  ('코스타리카', 3),
#  ('핀란드', 3),
#  ('아일랜드', 3),
#  ('헝가리', 3),
#  ('크리스마스', 3),
#  ('이집트', 3),
#  ('가나', 3),
#  ('중동', 3),
#  ('라오스', 2),
#  ('우즈베키스탄', 2),
#  ('온두라스', 2),
#  ('쿠바', 2),
#  ('에콰도르', 2),
#  ('스웨덴', 2),
#  ('에스토니아', 2),
#  ('슬로베니아', 2),
#  ('아랍', 2),
#  ('아메리카', 2),
#  ('캄보디아', 1),
#  ('몰디브', 1),
#  ('이라크', 1),
#  ('키르기스스탄', 1),
#  ('자메이카', 1),
#  ('칠레', 1),
#  ('덴마크', 1),
#  ('노르웨이', 1),
#  ('오스트리아', 1),
#  ('리투아니아', 1),
#  ('라트비아', 1),
#  ('뉴질랜드', 1),
#  ('괌', 1),
#  ('에티오피아', 1),
#  ('모리셔스', 1),
#  ('우간다', 1),
#  ('콩고', 1),
#  ('동남아시아', 1),
#  ('동유럽', 1),
#  ('북유럽', 1)]

# %%
df['date'] = [ datetime.datetime.strptime(df.loc[i, 'date'][:-10], '%Y-%m-%d') for i in range(len(df)) ]

# %%
date_count = df['date'].value_counts()

# %%
from pyecharts import Bar, Line
line = Line()
line.add("line", date_count.keys(), date_count.values)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5c05bb4b7d244766a9a37840a493fb27" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5c05bb4b7d244766a9a37840a493fb27 = echarts.init(document.getElementById('5c05bb4b7d244766a9a37840a493fb27'), 'light', {renderer: 'canvas'});
#
# var option_5c05bb4b7d244766a9a37840a493fb27 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4759773,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2020-09-01T00:00:00",
#                     27.0
#                 ],
#                 [
#                     "2021-05-22T00:00:00",
#                     23.0
#                 ],
#                 [
#                     "2020-12-11T00:00:00",
#                     22.0
#                 ],
#                 [
#                     "2021-04-06T00:00:00",
#                     22.0
#                 ],
#                 [
#                     "2020-11-10T00:00:00",
#                     22.0
#                 ],
#                 [
#                     "2020-09-19T00:00:00",
#                     21.0
#                 ],
#                 [
#                     "2021-01-09T00:00:00",
#                     21.0
#                 ],
#                 [
#                     "2020-09-07T00:00:00",
#                     21.0
#                 ],
#                 [
#                     "2020-07-18T00:00:00",
#                     21.0
#                 ],
#                 [
#                     "2020-09-23T00:00:00",
#                     21.0
#                 ],
#                 [
#                     "2020-10-30T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2021-01-05T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2020-11-25T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2021-05-21T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2021-01-22T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2021-01-29T00:00:00",
#                     20.0
#                 ],
#                 [
#                     "2020-10-16T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-01-26T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-09-18T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-10-24T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-10-28T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-03-30T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-06-06T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-01-31T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-05-28T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-07-24T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-04-09T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-08-11T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-02-11T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-03-09T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2020-10-02T00:00:00",
#                     19.0
#                 ],
#                 [
#                     "2021-04-23T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-02-19T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-07-25T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-08-21T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-06-25T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-09-24T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-08-03T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-04-22T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-06-19T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-01-16T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-07-30T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-05-05T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-09-11T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-04-14T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2020-08-07T00:00:00",
#                     18.0
#                 ],
#                 [
#                     "2021-04-02T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2021-02-26T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-08-13T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-08-18T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2021-06-18T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-12-17T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-12-30T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2021-02-27T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2021-03-10T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-12-04T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-11-20T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-11-16T00:00:00",
#                     17.0
#                 ],
#                 [
#                     "2020-11-24T00:00:00",
#                     17.0
